# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# from sklearn.model_selection

pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv('balanced_dataset_12k.csv')

# %%
df.head()
# Out:
#                                                                                                                                   headline  \
# 0  How JD(S) is quietly remaking its leadership team: As a veteran MLA is removed from core committee, ‘first family’ scions get key posts
# 1                                                  Waqf Bill: More than 12 hours of debate, and a washroom break that got Congress all wet
# 2                                                     India-U.S. interim trade deal: ‘Namaste Trump scored over Howdy Modi’, says Congress
# 3                                     ‘Richest’ CM Chandrababu Naidu’s draws almost entirely on one asset, Mamata records sharpest decline
# 4                                                         Sunil Jakhar ‘resignation’: How ex-Congress leader struggled to find feet in BJP
#
#        label  confidence
# 0  sarcastic        0.65
# 1  sarcastic        0.85
# 2  sarcastic        0.75
# 3  sarcastic        0.45
# 4  sarcastic        0.45

# %%
df = df.drop(columns=['confidence'], axis = 1)

# %%
df['clean_text'] = df['headline'].str.lower()
df.head()
# Out:
#                                                                                                                                   headline  \
# 0  How JD(S) is quietly remaking its leadership team: As a veteran MLA is removed from core committee, ‘first family’ scions get key posts
# 1                                                  Waqf Bill: More than 12 hours of debate, and a washroom break that got Congress all wet
# 2                                                     India-U.S. interim trade deal: ‘Namaste Trump scored over Howdy Modi’, says Congress
# 3                                     ‘Richest’ CM Chandrababu Naidu’s draws almost entirely on one asset, Mamata records sharpest decline
# 4                                                         Sunil Jakhar ‘resignation’: How ex-Congress leader struggled to find feet in BJP
#
#        label  \
# 0  sarcastic
# 1  sarcastic
# 2  sarcastic
# 3  sarcastic
# 4  sarcastic
#
#                                                                                                                                 clean_text
# 0  how jd(s) is quietly remaking its leadership team: as a veteran mla is removed from core committee, ‘first family’ scions get key posts
# 1                                                  waqf bill: more than 12 hours of debate, and a washroom break that got congress all wet
# 2                                                     india-u.s. interim trade deal: ‘namaste trump scored over howdy modi’, says congress
# 3                                     ‘richest’ cm chandrababu naidu’s draws almost entirely on one asset, mamata records sharpest decline
# 4                                                         sunil jakhar ‘resignation’: how ex-congress leader struggled to find feet in bjp

# %%
import string
def remove_punctuations(text):
    punctuations = string.punctuation
    return text.translate(str.maketrans('', '', punctuations))

df['clean_text'] = df['clean_text'].apply(lambda x: remove_punctuations(x))
df.head()
# Out:
#                                                                                                                                   headline  \
# 0  How JD(S) is quietly remaking its leadership team: As a veteran MLA is removed from core committee, ‘first family’ scions get key posts
# 1                                                  Waqf Bill: More than 12 hours of debate, and a washroom break that got Congress all wet
# 2                                                     India-U.S. interim trade deal: ‘Namaste Trump scored over Howdy Modi’, says Congress
# 3                                     ‘Richest’ CM Chandrababu Naidu’s draws almost entirely on one asset, Mamata records sharpest decline
# 4                                                         Sunil Jakhar ‘resignation’: How ex-Congress leader struggled to find feet in BJP
#
#        label  \
# 0  sarcastic
# 1  sarcastic
# 2  sarcastic
# 3  sarcastic
# 4  sarcastic
#
#                                                                                                                             clean_text
# 0  how jds is quietly remaking its leadership team as a veteran mla is removed from core committee ‘first family’ scions get key posts
# 1                                                waqf bill more than 12 hours of debate and a washroom break that got congress all wet
# 2                                                      indiaus interim trade deal ‘namaste trump scored over howdy modi’ says congress
# 3                                  ‘richest’ cm chandrababu naidu’s draws almost entirely on one asset mamata records sharpest decline
# 4                                                       sunil jakhar ‘resignation’ how excongress leader struggled to find feet in bjp

# %%
import nltk

nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/jupyter/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/jupyter/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
", ".join(stopwords.words('english'))
# Out:
# "a, about, above, after, again, against, ain, all, am, an, and, any, are, aren, aren't, as, at, be, because, been, before, being, below, between, both, but, by, can, couldn, couldn't, d, did, didn, didn't, do, does, doesn, doesn't, doing, don, don't, down, during, each, few, for, from, further, had, hadn, hadn't, has, hasn, hasn't, have, haven, haven't, having, he, he'd, he'll, her, here, hers, herself, he's, him, himself, his, how, i, i'd, if, i'll, i'm, in, into, is, isn, isn't, it, it'd, it'll, it's, its, itself, i've, just, ll, m, ma, me, mightn, mightn't, more, most, mustn, mustn't, my, myself, needn, needn't, no, nor, not, now, o, of, off, on, once, only, or, other, our, ours, ourselves, out, over, own, re, s, same, shan, shan't, she, she'd, she'll, she's, should, shouldn, shouldn't, should've, so, some, such, t, than, that, that'll, the, their, theirs, them, themselves, then, there, these, they, they'd, they'll, they're, they've, this, those, through, to, too, under, until, up, ve, very, was, wasn, wasn't, we, we'd, we'll, we're, were, weren, weren't, we've, what, when, where, which, while, who, whom, why, will, with, won, won't, wouldn, wouldn't, y, you, you'd, you'll, your, you're, yours, yourself, yourselves, you've"

# %%
STOPWORDS = set(stopwords.words('english'))
def remove_stopwords(text):
    return " ".join([word for word in text.split() if word not in STOPWORDS])

df['clean_text'] = df['clean_text'].apply(lambda x: remove_stopwords(x))
df.head()
# Out:
#                                                                                                                                   headline  \
# 0  How JD(S) is quietly remaking its leadership team: As a veteran MLA is removed from core committee, ‘first family’ scions get key posts
# 1                                                  Waqf Bill: More than 12 hours of debate, and a washroom break that got Congress all wet
# 2                                                     India-U.S. interim trade deal: ‘Namaste Trump scored over Howdy Modi’, says Congress
# 3                                     ‘Richest’ CM Chandrababu Naidu’s draws almost entirely on one asset, Mamata records sharpest decline
# 4                                                         Sunil Jakhar ‘resignation’: How ex-Congress leader struggled to find feet in BJP
#
#        label  \
# 0  sarcastic
# 1  sarcastic
# 2  sarcastic
# 3  sarcastic
# 4  sarcastic
#
#                                                                                                     clean_text
# 0  jds quietly remaking leadership team veteran mla removed core committee ‘first family’ scions get key posts
# 1                                                    waqf bill 12 hours debate washroom break got congress wet
# 2                                   indiaus interim trade deal ‘namaste trump scored howdy modi’ says congress
# 3             ‘richest’ cm chandrababu naidu’s draws almost entirely one asset mamata records sharpest decline
# 4                                         sunil jakhar ‘resignation’ excongress leader struggled find feet bjp

# %%
import re

def clean_text(text):
    # 1. Normalize weird unicode quotes → standard ones
    text = text.replace("’", "'").replace("‘", "'")
    text = text.replace("“", '"').replace("”", '"')

    # 2. Replace ellipsis with normal dots
    text = text.replace("…", "...")

    # 3. Remove unwanted symbols (but KEEP ! ? ' ")
    text = re.sub(r"[^a-zA-Z0-9\s!?\'\"]", " ", text)

    # 4. Remove extra spaces
    text = re.sub(r"\s+", " ", text).strip()

    return text

df['clean_text'] = df['clean_text'].apply(lambda x: clean_text(x))
df.head()
# Out:
#                                                                                                                                   headline  \
# 0  How JD(S) is quietly remaking its leadership team: As a veteran MLA is removed from core committee, ‘first family’ scions get key posts
# 1                                                  Waqf Bill: More than 12 hours of debate, and a washroom break that got Congress all wet
# 2                                                     India-U.S. interim trade deal: ‘Namaste Trump scored over Howdy Modi’, says Congress
# 3                                     ‘Richest’ CM Chandrababu Naidu’s draws almost entirely on one asset, Mamata records sharpest decline
# 4                                                         Sunil Jakhar ‘resignation’: How ex-Congress leader struggled to find feet in BJP
#
#        label  \
# 0  sarcastic
# 1  sarcastic
# 2  sarcastic
# 3  sarcastic
# 4  sarcastic
#
#                                                                                                     clean_text
# 0  jds quietly remaking leadership team veteran mla removed core committee 'first family' scions get key posts
# 1                                                    waqf bill 12 hours debate washroom break got congress wet
# 2                                   indiaus interim trade deal 'namaste trump scored howdy modi' says congress
# 3             'richest' cm chandrababu naidu's draws almost entirely one asset mamata records sharpest decline
# 4                                         sunil jakhar 'resignation' excongress leader struggled find feet bjp

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (3.9.4)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk) (2026.3.32)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk) (4.67.3)

# %%
from nltk.tokenize import TweetTokenizer

tokenizer = TweetTokenizer()
df['clean_text'] = df['clean_text'].apply(lambda x: tokenizer.tokenize(x))
df.head()
# Out:
#                                                                                                                                   headline  \
# 0  How JD(S) is quietly remaking its leadership team: As a veteran MLA is removed from core committee, ‘first family’ scions get key posts
# 1                                                  Waqf Bill: More than 12 hours of debate, and a washroom break that got Congress all wet
# 2                                                     India-U.S. interim trade deal: ‘Namaste Trump scored over Howdy Modi’, says Congress
# 3                                     ‘Richest’ CM Chandrababu Naidu’s draws almost entirely on one asset, Mamata records sharpest decline
# 4                                                         Sunil Jakhar ‘resignation’: How ex-Congress leader struggled to find feet in BJP
#
#        label  \
# 0  sarcastic
# 1  sarcastic
# 2  sarcastic
# 3  sarcastic
# 4  sarcastic
#
#                                                                                                                          clean_text
# 0  [jds, quietly, remaking, leadership, team, veteran, mla, removed, core, committee, ', first, family, ', scions, get, key, posts]
# 1                                                              [waqf, bill, 12, hours, debate, washroom, break, got, congress, wet]
# 2                                        [indiaus, interim, trade, deal, ', namaste, trump, scored, howdy, modi, ', says, congress]
# 3                [', richest, ', cm, chandrababu, naidu's, draws, almost, entirely, one, asset, mamata, records, sharpest, decline]
# 4                                                [sunil, jakhar, ', resignation, ', excongress, leader, struggled, find, feet, bjp]

# %%
df['text_for_bow'] = df['clean_text'].apply(
    lambda tokens: " ".join([word for word in tokens if word != "'"])
)

# %%
df.head()
# Out:
#                                                                                                                                   headline  \
# 0  How JD(S) is quietly remaking its leadership team: As a veteran MLA is removed from core committee, ‘first family’ scions get key posts
# 1                                                  Waqf Bill: More than 12 hours of debate, and a washroom break that got Congress all wet
# 2                                                     India-U.S. interim trade deal: ‘Namaste Trump scored over Howdy Modi’, says Congress
# 3                                     ‘Richest’ CM Chandrababu Naidu’s draws almost entirely on one asset, Mamata records sharpest decline
# 4                                                         Sunil Jakhar ‘resignation’: How ex-Congress leader struggled to find feet in BJP
#
#        label  \
# 0  sarcastic
# 1  sarcastic
# 2  sarcastic
# 3  sarcastic
# 4  sarcastic
#
#                                                                                                                          clean_text  \
# 0  [jds, quietly, remaking, leadership, team, veteran, mla, removed, core, committee, ', first, family, ', scions, get, key, posts]
# 1                                                              [waqf, bill, 12, hours, debate, washroom, break, got, congress, wet]
# 2                                        [indiaus, interim, trade, deal, ', namaste, trump, scored, howdy, modi, ', says, congress]
# 3                [', richest, ', cm, chandrababu, naidu's, draws, almost, entirely, one, asset, mamata, records, sharpest, decline]
# 4                                                [sunil, jakhar, ', resignation, ', excongress, leader, struggled, find, feet, bjp]
#
#                                                                                                 text_for_bow
# 0  jds quietly remaking leadership team veteran mla removed core committee first family scions get key posts
# 1                                                  waqf bill 12 hours debate washroom break got congress wet
# 2                                   indiaus interim trade deal namaste trump scored howdy modi says congress
# 3             richest cm chandrababu naidu's draws almost entirely one asset mamata records sharpest decline
# 4                                         sunil jakhar resignation excongress leader struggled find feet bjp

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()

X = vectorizer.fit_transform(df['text_for_bow'])

y = df['label']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20,   # 30% goes to temp (val + test)
    random_state=42,
    stratify=y        # VERY IMPORTANT for classification
)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_jobs=-1,
    random_state=42
)

rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=42)

# %%
y_test_pred = rf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

print("Validation Accuracy:", accuracy_score(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred))
# Out:
# Validation Accuracy: 0.6601612218922359
#                precision    recall  f1-score   support
#
# non-sarcastic       0.69      0.58      0.63      1179
#     sarcastic       0.64      0.74      0.68      1178
#
#      accuracy                           0.66      2357
#     macro avg       0.66      0.66      0.66      2357
#  weighted avg       0.66      0.66      0.66      2357

# %%
from sklearn.svm import SVC

svm = SVC(
    kernel='linear',
    random_state=42
)

svm.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
y_test_pred = svm.predict(X_test)

# %%
print("Validation Accuracy:", accuracy_score(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred))
# Out:
# Validation Accuracy: 0.6342808655070005
#                precision    recall  f1-score   support
#
# non-sarcastic       0.63      0.64      0.64      1179
#     sarcastic       0.64      0.62      0.63      1178
#
#      accuracy                           0.63      2357
#     macro avg       0.63      0.63      0.63      2357
#  weighted avg       0.63      0.63      0.63      2357

# %%
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV

param_grid = {
    'n_estimators': [100, 200, 300, 500],
    
    'max_depth': [None, 10, 20, 30, 50],
    
    'min_samples_split': [2, 5, 10],
    
    'min_samples_leaf': [1, 2, 4],
    
    'max_features': ['sqrt', 'log2', None],
    
    'bootstrap': [True, False],
    
    'criterion': ['gini', 'entropy']
}

from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV

from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

param_grid = {
    # CORE (most impact)
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 30, None],
    'max_features': ['sqrt', 0.5],

    # REGULARIZATION (important but controlled)
    'min_samples_split': [2, 10],
    'min_samples_leaf': [1, 3],

    # LIGHT extras (small exploration only)
    'bootstrap': [True],
    'criterion': ['gini', 'log_loss']
}

halving = HalvingGridSearchCV(
    RandomForestClassifier(
        random_state=42,
        n_jobs=1
    ),
    param_grid,
    cv=cv,
    factor=3,
    scoring='f1_weighted',
    n_jobs=-1,
    verbose=3
)

halving.fit(X_train, y_train)

print("Best Params:", halving.best_params_)
# Out:
# n_iterations: 5
# n_required_iterations: 5
# n_possible_iterations: 5
# min_resources_: 116
# max_resources_: 9427
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 144
# n_resources: 116
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.989, test=0.577) total time=   0.4s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.989, test=0.415) total time=   0.2s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=1.000, test=0.318) total time=   0.2s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.586, test=0.358) total time=   0.4s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.370, test=0.220) total time=   0.2s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=200;, score=(train=0.358, test=0.408) total time=   0.4s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.358, test=0.408) total time=   0.2s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.416, test=0.408) total time=   0.2s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=200;, score=(train=0.370, test=0.220) total time=   0.4s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.934, test=0.318) total time=   1.0s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.798, test=0.421) total time=   1.9s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.956, test=0.553) total time=   1.0s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.935, test=0.610) total time=   1.8s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=0.770, test=0.448) total time=   2.7s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=300;, score=(train=0.760, test=0.466) total time=   2.7s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=300;, score=(train=0.779, test=0.379) total time=   2.8s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=1.000, test=0.358) total time=   0.7s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=1.000, test=0.414) total time=   0.3s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=1.000, test=0.646) total time=   0.3s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.967, test=0.358) total time=   0.3s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=1.000, test=0.504) total time=   0.9s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=200;, score=(train=0.358, test=0.408) total time=   0.4s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=300;, score=(train=0.370, test=0.220) total time=   0.6s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300;, score=(train=0.358, test=0.408) total time=   0.5s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=1.000, test=0.478) total time=   1.1s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=1.000, test=0.575) total time=   3.2s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=1.000, test=0.530) total time=   2.0s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.791, test=0.343) total time=   0.9s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.703, test=0.437) total time=   0.9s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=200;, score=(train=0.760, test=0.466) total time=   1.8s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.791, test=0.343) total time=   0.9s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.750, test=0.338) total time=   0.8s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=200;, score=(train=0.740, test=0.338) total time=   1.7s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=1.000, test=0.474) total time=   0.5s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=1.000, test=0.358) total time=   0.5s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=1.000, test=0.358) total time=   0.9s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=1.000, test=0.356) total time=   0.4s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=1.000, test=0.444) total time=   0.4s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=1.000, test=0.220) total time=   0.7s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.358, test=0.408) total time=   0.2s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.370, test=0.220) total time=   0.2s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=200;, score=(train=0.358, test=0.408) total time=   0.4s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=300;, score=(train=0.358, test=0.408) total time=   0.5s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.818, test=0.220) total time=   0.2s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=0.901, test=0.220) total time=   0.7s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=1.000, test=0.471) total time=   0.4s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.358, test=0.408) total time=   0.2s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.474, test=0.358) total time=   0.2s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=300;, score=(train=0.358, test=0.408) total time=   0.5s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=200;, score=(train=0.358, test=0.408) total time=   0.4s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300;, score=(train=0.474, test=0.358) total time=   0.5s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=1.000, test=0.530) total time=   2.0s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.902, test=0.318) total time=   0.9s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.989, test=0.348) total time=   0.9s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.770, test=0.448) total time=   1.8s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.783, test=0.466) total time=   0.9s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=200;, score=(train=0.789, test=0.356) total time=   1.8s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=300;, score=(train=0.704, test=0.437) total time=   2.7s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=300;, score=(train=0.670, test=0.276) total time=   2.8s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=1.000, test=0.343) total time=   1.3s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=1.000, test=0.415) total time=   0.7s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.358, test=0.408) total time=   0.2s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.416, test=0.408) total time=   0.2s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=200;, score=(train=0.370, test=0.220) total time=   0.4s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=300;, score=(train=0.345, test=0.408) total time=   0.6s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300;, score=(train=0.358, test=0.408) total time=   0.5s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=1.000, test=0.421) total time=   1.1s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=1.000, test=0.530) total time=   3.2s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=1.000, test=0.448) total time=   2.0s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.654, test=0.594) total time=   0.9s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.750, test=0.338) total time=   0.9s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=200;, score=(train=0.715, test=0.437) total time=   1.8s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.654, test=0.594) total time=   0.8s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.703, test=0.437) total time=   0.8s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=200;, score=(train=0.715, test=0.437) total time=   1.7s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=1.000, test=0.220) total time=   0.5s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=1.000, test=0.356) total time=   1.0s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=1.000, test=0.435) total time=   1.4s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=1.000, test=0.358) total time=   0.7s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.416, test=0.408) total time=   0.2s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=200;, score=(train=0.358, test=0.408) total time=   0.3s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=200;, score=(train=0.474, test=0.358) total time=   0.4s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.370, test=0.220) total time=   0.2s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=200;, score=(train=0.358, test=0.408) total time=   0.3s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300;, score=(train=0.345, test=0.408) total time=   0.5s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=1.000, test=0.575) total time=   2.1s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.989, test=0.415) total time=   0.2s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.605, test=0.358) total time=   0.4s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.818, test=0.220) total time=   0.2s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.989, test=0.577) total time=   0.4s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=1.000, test=0.471) total time=   0.6s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=300;, score=(train=0.358, test=0.408) total time=   0.5s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=200;, score=(train=0.474, test=0.358) total time=   0.4s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.978, test=0.553) total time=   1.0s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=0.912, test=0.318) total time=   2.9s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.913, test=0.343) total time=   1.7s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=1.000, test=0.350) total time=   2.7s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=300;, score=(train=0.670, test=0.276) total time=   2.6s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=200;, score=(train=0.715, test=0.437) total time=   1.8s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=1.000, test=0.610) total time=   0.3s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=1.000, test=0.358) total time=   0.4s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=1.000, test=0.220) total time=   0.7s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=1.000, test=0.504) total time=   1.1s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=1.000, test=0.610) total time=   0.7s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=1.000, test=0.444) total time=   1.0s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.358, test=0.408) total time=   0.2s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.416, test=0.408) total time=   0.2s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=200;, score=(train=0.345, test=0.408) total time=   0.4s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=1.000, test=0.545) total time=   1.1s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=1.000, test=0.421) total time=   2.1s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.989, test=0.642) total time=   1.0s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.978, test=0.343) total time=   2.0s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=1.000, test=0.307) total time=   3.1s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=300;, score=(train=0.670, test=0.276) total time=   2.6s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=200;, score=(train=0.760, test=0.466) total time=   1.7s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=1.000, test=0.518) total time=   0.5s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=1.000, test=0.356) total time=   0.5s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=1.000, test=0.356) total time=   1.0s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=1.000, test=0.540) total time=   0.4s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=1.000, test=0.358) total time=   0.4s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=1.000, test=0.557) total time=   0.7s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=1.000, test=0.358) total time=   1.1s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.358, test=0.408) total time=   0.2s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.416, test=0.408) total time=   0.2s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300;, score=(train=0.358, test=0.408) total time=   0.5s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=1.000, test=0.478) total time=   1.1s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=1.000, test=0.575) total time=   3.2s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=1.000, test=0.530) total time=   2.0s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.791, test=0.343) total time=   0.9s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.586, test=0.358) total time=   0.2s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=0.989, test=0.577) total time=   0.6s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.978, test=0.388) total time=   0.4s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=0.605, test=0.358) total time=   0.7s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=300;, score=(train=0.370, test=0.220) total time=   0.5s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300;, score=(train=0.358, test=0.408) total time=   0.5s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.989, test=0.394) total time=   1.0s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=0.956, test=0.610) total time=   2.7s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.967, test=0.530) total time=   1.8s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.791, test=0.343) total time=   0.9s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.715, test=0.437) total time=   0.9s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=200;, score=(train=0.715, test=0.437) total time=   1.8s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.654, test=0.594) total time=   0.8s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.750, test=0.338) total time=   0.9s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=200;, score=(train=0.740, test=0.338) total time=   1.8s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=1.000, test=0.220) total time=   0.3s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=1.000, test=0.318) total time=   0.7s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=1.000, test=0.444) total time=   0.6s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=1.000, test=0.444) total time=   1.0s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.967, test=0.358) total time=   0.6s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.370, test=0.220) total time=   0.2s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=200;, score=(train=0.358, test=0.408) total time=   0.3s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=300;, score=(train=0.358, test=0.408) total time=   0.5s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=200;, score=(train=0.358, test=0.408) total time=   0.4s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300;, score=(train=0.474, test=0.358) total time=   0.5s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=1.000, test=0.530) total time=   2.1s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.978, test=0.356) total time=   1.0s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=1.000, test=0.437) total time=   1.0s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=1.000, test=0.350) total time=   2.1s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.783, test=0.466) total time=   0.9s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=200;, score=(train=0.789, test=0.356) total time=   1.8s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=300;, score=(train=0.704, test=0.437) total time=   2.6s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=300;, score=(train=0.779, test=0.379) total time=   2.5s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=1.000, test=0.220) total time=   1.0s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=1.000, test=0.356) total time=   1.4s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=1.000, test=0.220) total time=   1.1s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=300;, score=(train=0.345, test=0.408) total time=   0.5s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=200;, score=(train=0.474, test=0.358) total time=   0.3s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=1.000, test=0.642) total time=   1.1s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=1.000, test=0.421) total time=   2.1s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.989, test=0.642) total time=   1.0s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.978, test=0.343) total time=   2.0s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=1.000, test=0.307) total time=   3.1s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.866, test=0.220) total time=   0.4s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=1.000, test=0.471) total time=   0.7s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=0.978, test=0.388) total time=   0.6s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=200;, score=(train=0.358, test=0.408) total time=   0.3s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=300;, score=(train=0.345, test=0.408) total time=   0.5s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300;, score=(train=0.370, test=0.220) total time=   0.5s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.934, test=0.318) total time=   1.9s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=0.798, test=0.421) total time=   2.8s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=0.945, test=0.530) total time=   2.7s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=200;, score=(train=0.740, test=0.338) total time=   1.8s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.783, test=0.466) total time=   0.8s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=200;, score=(train=0.789, test=0.356) total time=   1.7s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=300;, score=(train=0.704, test=0.437) total time=   2.9s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=1.000, test=0.220) total time=   0.3s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=1.000, test=0.292) total time=   0.8s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.358, test=0.408) total time=   0.2s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.474, test=0.358) total time=   0.2s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=200;, score=(train=0.345, test=0.408) total time=   0.4s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=300;, score=(train=0.474, test=0.358) total time=   0.5s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300;, score=(train=0.370, test=0.220) total time=   0.5s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=1.000, test=0.343) total time=   2.2s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=1.000, test=0.421) total time=   3.1s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=1.000, test=0.575) total time=   3.1s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=200;, score=(train=0.740, test=0.338) total time=   1.8s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.783, test=0.466) total time=   0.8s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=200;, score=(train=0.789, test=0.356) total time=   1.7s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=300;, score=(train=0.704, test=0.437) total time=   2.6s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=1.000, test=0.220) total time=   0.4s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=1.000, test=0.318) total time=   0.7s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=1.000, test=0.343) total time=   1.1s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=200;, score=(train=0.345, test=0.408) total time=   0.3s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.358, test=0.408) total time=   0.2s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.474, test=0.358) total time=   0.2s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300;, score=(train=0.358, test=0.408) total time=   0.5s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=1.000, test=0.421) total time=   1.1s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=1.000, test=0.530) total time=   3.2s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=1.000, test=0.350) total time=   2.1s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.654, test=0.594) total time=   0.9s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.750, test=0.338) total time=   0.9s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=200;, score=(train=0.715, test=0.437) total time=   1.8s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.654, test=0.594) total time=   0.8s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.750, test=0.338) total time=   0.8s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=200;, score=(train=0.740, test=0.338) total time=   1.8s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.989, test=0.388) total time=   0.5s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=0.624, test=0.358) total time=   0.7s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=0.989, test=0.577) total time=   0.6s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=200;, score=(train=0.345, test=0.408) total time=   0.3s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.358, test=0.408) total time=   0.2s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.474, test=0.358) total time=   0.2s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=200;, score=(train=0.345, test=0.408) total time=   0.3s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.889, test=0.610) total time=   0.9s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.989, test=0.307) total time=   1.8s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.878, test=0.610) total time=   0.9s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.755, test=0.448) total time=   0.9s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=0.891, test=0.318) total time=   2.5s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=200;, score=(train=0.660, test=0.276) total time=   1.7s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=300;, score=(train=0.730, test=0.338) total time=   2.7s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=300;, score=(train=0.760, test=0.466) total time=   3.0s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=0.989, test=0.358) total time=   1.2s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=1.000, test=0.220) total time=   1.0s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=300;, score=(train=0.358, test=0.408) total time=   0.6s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=200;, score=(train=0.370, test=0.220) total time=   0.4s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=1.000, test=0.356) total time=   1.1s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=1.000, test=0.430) total time=   2.1s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=1.000, test=0.545) total time=   1.0s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=1.000, test=0.448) total time=   1.0s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=0.978, test=0.318) total time=   2.9s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=200;, score=(train=0.660, test=0.276) total time=   1.7s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=300;, score=(train=0.730, test=0.338) total time=   2.7s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=300;, score=(train=0.760, test=0.466) total time=   2.5s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=1.000, test=0.415) total time=   1.5s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=1.000, test=0.444) total time=   0.7s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.358, test=0.408) total time=   0.2s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.474, test=0.358) total time=   0.2s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=200;, score=(train=0.370, test=0.220) total time=   0.4s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=300;, score=(train=0.370, test=0.220) total time=   0.5s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=200;, score=(train=0.345, test=0.408) total time=   0.4s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=1.000, test=0.545) total time=   1.1s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=1.000, test=0.318) total time=   3.2s
# ...
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=200;, score=(train=0.783, test=0.530) total time=   1.7s
# [CV 1/5] END bootstrap=True, criterion=log_loss, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.993, test=0.559) total time=   0.4s
# [CV 2/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.996, test=0.362) total time=   0.7s
# [CV 1/5] END bootstrap=True, criterion=log_loss, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.978, test=0.604) total time=   3.6s
# [CV 4/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.993, test=0.539) total time=   4.6s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.795, test=0.560) total time=   1.7s
# [CV 5/5] END bootstrap=True, criterion=log_loss, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.780, test=0.566) total time=   1.1s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.748, test=0.583) total time=   1.2s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.802, test=0.592) total time=   1.8s
# [CV 4/5] END bootstrap=True, criterion=log_loss, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.793, test=0.677) total time=   1.2s
# [CV 2/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.801, test=0.634) total time=   1.6s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=0.946, test=0.579) total time=   5.3s
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=1.000, test=0.593) total time=   5.7s
# [CV 4/5] END bootstrap=True, criterion=log_loss, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.946, test=0.551) total time=   3.8s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=0.902, test=0.609) total time=   3.8s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.982, test=0.681) total time=   3.6s
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=0.914, test=0.604) total time=   3.6s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=0.776, test=0.493) total time=   3.9s
# [CV 1/5] END bootstrap=True, criterion=log_loss, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.989, test=0.572) total time=   1.9s
# [CV 2/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=1.000, test=0.595) total time=   2.4s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=1.000, test=0.607) total time=   7.0s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.805, test=0.567) total time=   1.3s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=1.000, test=0.555) total time=   4.8s
# [CV 2/5] END bootstrap=True, criterion=log_loss, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.785, test=0.504) total time=   1.3s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.858, test=0.593) total time=   1.3s
# [CV 1/5] END bootstrap=True, criterion=log_loss, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.844, test=0.593) total time=   2.5s
# [CV 4/5] END bootstrap=True, criterion=log_loss, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.935, test=0.576) total time=   1.8s
# [CV 2/5] END bootstrap=True, criterion=log_loss, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.776, test=0.524) total time=   2.6s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.960, test=0.581) total time=   1.8s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.996, test=0.639) total time=   1.9s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.875, test=0.565) total time=   8.8s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=0.953, test=0.596) total time=  12.7s
# [CV 4/5] END bootstrap=True, criterion=log_loss, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.915, test=0.592) total time=   8.4s
# [CV 2/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.863, test=0.575) total time=   5.9s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.813, test=0.615) total time=   3.9s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.882, test=0.566) total time=   3.9s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.833, test=0.596) total time=   5.1s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.820, test=0.615) total time=   3.5s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=0.998, test=0.620) total time=  21.6s
# [CV 1/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.884, test=0.618) total time=  25.8s
# ----------
# iter: 4
# n_candidates: 2
# n_resources: 9396
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.935, test=0.505) total time=   0.3s
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=1.000, test=0.512) total time=   0.9s
# [CV 5/5] END bootstrap=True, criterion=log_loss, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.942, test=0.585) total time=   3.7s
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.780, test=0.582) total time=   1.7s
# [CV 4/5] END bootstrap=True, criterion=log_loss, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.795, test=0.649) total time=   1.6s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.788, test=0.595) total time=   1.6s
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.734, test=0.608) total time=   1.1s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.806, test=0.636) total time=   1.6s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.719, test=0.621) total time=   1.2s
# [CV 1/5] END bootstrap=True, criterion=log_loss, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.782, test=0.542) total time=   1.2s
# [CV 5/5] END bootstrap=True, criterion=log_loss, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.777, test=0.566) total time=   1.2s
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.784, test=0.582) total time=   1.6s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=1.000, test=0.588) total time=   6.8s
# [CV 4/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=1.000, test=0.563) total time=   4.9s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.858, test=0.581) total time=   2.6s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=0.787, test=0.493) total time=   4.1s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.975, test=0.638) total time=   3.5s
# [CV 1/5] END bootstrap=True, criterion=log_loss, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=0.858, test=0.606) total time=   3.9s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=0.888, test=0.669) total time=   3.5s
# [CV 5/5] END bootstrap=True, criterion=log_loss, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=0.807, test=0.606) total time=   3.6s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=1.000, test=0.698) total time=   7.2s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.866, test=0.638) total time=   1.2s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.993, test=0.638) total time=   3.7s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=1.000, test=0.561) total time=   4.7s
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.892, test=0.665) total time=   2.4s
# [CV 1/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.996, test=0.608) total time=   2.3s
# [CV 4/5] END bootstrap=True, criterion=log_loss, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.884, test=0.649) total time=   2.6s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.978, test=0.654) total time=   1.8s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=1.000, test=0.485) total time=   2.3s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.950, test=0.582) total time=   8.5s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=0.919, test=0.563) total time=  12.8s
# [CV 2/5] END bootstrap=True, criterion=log_loss, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.911, test=0.531) total time=   8.2s
# [CV 5/5] END bootstrap=True, criterion=log_loss, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=0.802, test=0.557) total time=   6.9s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.821, test=0.610) total time=   4.0s
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.879, test=0.572) total time=   5.6s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.780, test=0.557) total time=   3.5s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.754, test=0.606) total time=   2.3s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=0.996, test=0.593) total time=  22.4s
# [CV 2/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.884, test=0.634) total time=  25.8s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=0.999, test=0.615) total time= 1.5min
# [CV 2/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.882, test=0.630) total time=  23.9s
# [CV 4/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.894, test=0.667) total time= 1.7min
# Best Params: {'bootstrap': True, 'criterion': 'log_loss', 'max_depth': None, 'max_features': 0.5, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 100}

# %%
best_rf = halving.best_estimator_

y_test_pred = best_rf.predict(X_test)

# %%
print("Test Accuracy:", accuracy_score(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred))
# Out:
# Test Accuracy: 0.6521001272804412
#                precision    recall  f1-score   support
#
# non-sarcastic       0.67      0.61      0.64      1179
#     sarcastic       0.64      0.70      0.67      1178
#
#      accuracy                           0.65      2357
#     macro avg       0.65      0.65      0.65      2357
#  weighted avg       0.65      0.65      0.65      2357

# %%
from sklearn.svm import LinearSVC

param_grid = {
    'C': np.logspace(-3, 2, 8),
    'class_weight': [None, 'balanced'],
    'tol': [1e-3, 1e-4, 1e-5],
    'max_iter': [5000, 10000]   # removed 1000 (too small)
}

halving1 = HalvingGridSearchCV(
    LinearSVC(),   # ✅ FIXED
    param_grid,
    cv=cv,
    factor=3,
    scoring='f1_weighted',
    n_jobs=-1,
    verbose=2
)

halving1.fit(X_train, y_train)

print("Best Params:", halving1.best_params_)
# Out:
# n_iterations: 5
# n_required_iterations: 5
# n_possible_iterations: 5
# min_resources_: 116
# max_resources_: 9427
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 96
# n_resources: 116
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.763, test=0.635) total time=   1.2s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.748, test=0.582) total time=   1.6s
# [CV 2/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.801, test=0.634) total time=   1.6s
# [CV 5/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.799, test=0.566) total time=   1.6s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=1.000, test=0.711) total time=   7.0s
# [CV 1/5] END bootstrap=True, criterion=log_loss, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.993, test=0.606) total time=   4.3s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.779, test=0.493) total time=   2.7s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=0.825, test=0.550) total time=   3.8s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.946, test=0.567) total time=   3.5s
# [CV 2/5] END bootstrap=True, criterion=log_loss, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=0.783, test=0.512) total time=   3.9s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=0.877, test=0.609) total time=   3.7s
# [CV 2/5] END bootstrap=True, criterion=log_loss, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.935, test=0.566) total time=   1.9s
# [CV 1/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=1.000, test=0.580) total time=   2.5s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=1.000, test=0.573) total time=   7.2s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.931, test=0.512) total time=   3.9s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=1.000, test=0.608) total time=   4.6s
# [CV 2/5] END bootstrap=True, criterion=log_loss, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.772, test=0.524) total time=   2.4s
# [CV 5/5] END bootstrap=True, criterion=log_loss, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.957, test=0.571) total time=   1.8s
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.914, test=0.665) total time=   2.5s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=1.000, test=0.613) total time=   2.2s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.982, test=0.623) total time=   1.8s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.946, test=0.604) total time=   9.1s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.996, test=0.586) total time=  16.1s
# [CV 2/5] END bootstrap=True, criterion=log_loss, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=0.782, test=0.536) total time=   6.9s
# [CV 4/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.862, test=0.594) total time=   5.9s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.890, test=0.591) total time=   4.2s
# [CV 5/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.869, test=0.629) total time=   5.7s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.815, test=0.571) total time=   3.6s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=0.995, test=0.563) total time=  22.2s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.859, test=0.605) total time=  20.7s
# [CV 4/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.892, test=0.616) total time=  25.4s
# [CV 5/5] END bootstrap=True, criterion=log_loss, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.779, test=0.621) total time=  11.0s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.999, test=0.590) total time= 1.0min
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.881, test=0.597) total time=  22.6s
# [CV 2/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.886, test=0.637) total time= 1.8min
# [CV] END C=0.001, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.001, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.001, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.001, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=1.000, test=0.595) total time=   2.1s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=0.877, test=0.563) total time=  13.1s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.996, test=0.597) total time=  15.5s
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=0.826, test=0.562) total time=   7.0s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.780, test=0.557) total time=   4.2s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.905, test=0.601) total time=   3.9s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.875, test=0.557) total time=   5.4s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.695, test=0.555) total time=   2.3s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.773, test=0.587) total time=   2.4s
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.826, test=0.601) total time=   3.7s
# [CV 1/5] END bootstrap=True, criterion=log_loss, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.796, test=0.562) total time=   3.5s
# [CV 4/5] END bootstrap=True, criterion=log_loss, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.830, test=0.570) total time=   4.0s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.749, test=0.611) total time=   2.4s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.727, test=0.572) total time=   2.4s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.838, test=0.623) total time=  22.1s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=0.999, test=0.600) total time= 1.5min
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.999, test=0.615) total time=  41.1s
# [CV 2/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.889, test=0.639) total time= 1.9min
# [CV] END C=0.001, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.001, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.001, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.001, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=1.000, test=0.524) total time=   2.6s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.993, test=0.516) total time=   2.4s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.989, test=0.581) total time=   2.0s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=1.000, test=0.620) total time=   2.2s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=(train=0.949, test=0.572) total time=  13.3s
# [CV 1/5] END bootstrap=True, criterion=log_loss, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.851, test=0.547) total time=   8.1s
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_depth=30, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.925, test=0.563) total time=   8.3s
# [CV 1/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.863, test=0.555) total time=   6.3s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.800, test=0.556) total time=   4.2s
# [CV 2/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.862, test=0.586) total time=   5.8s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.853, test=0.615) total time=   5.6s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=1.000, test=0.562) total time=  22.9s
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.884, test=0.596) total time=  24.6s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=1.000, test=0.627) total time= 1.5min
# [CV 1/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.883, test=0.613) total time=  23.5s
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.891, test=0.642) total time= 1.7min
# [CV 5/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.894, test=0.661) total time= 1.2min
# [CV] END C=0.001, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.001, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV 4/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.861, test=0.600) total time=   5.6s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.811, test=0.610) total time=   3.5s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.754, test=0.561) total time=   2.4s
# [CV 1/5] END bootstrap=True, criterion=log_loss, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.797, test=0.557) total time=   3.7s
# [CV 4/5] END bootstrap=True, criterion=log_loss, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.830, test=0.570) total time=   3.7s
# [CV 2/5] END bootstrap=True, criterion=log_loss, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.827, test=0.583) total time=   3.7s
# [CV 5/5] END bootstrap=True, criterion=log_loss, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.828, test=0.606) total time=   4.1s
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.767, test=0.587) total time=   2.3s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.856, test=0.588) total time=  20.8s
# [CV 5/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.886, test=0.625) total time=  24.9s
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.748, test=0.563) total time=  10.5s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.998, test=0.608) total time= 1.1min
# [CV 4/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.891, test=0.618) total time=  22.8s
# [CV 1/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.891, test=0.640) total time= 1.9min
# [CV] END C=0.001, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.001, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.001, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.001, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# ----------
# iter: 1
# n_candidates: 32
# n_resources: 348
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.725, test=0.582) total time=   2.4s
# [CV 2/5] END bootstrap=True, criterion=log_loss, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.827, test=0.579) total time=   3.7s
# [CV 5/5] END bootstrap=True, criterion=log_loss, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.832, test=0.606) total time=   3.7s
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.828, test=0.606) total time=   3.6s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.695, test=0.551) total time=   2.3s
# [CV 3/5] END bootstrap=True, criterion=gini, max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.753, test=0.570) total time=   2.3s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.852, test=0.619) total time=  21.5s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=0.998, test=0.610) total time= 1.6min
# [CV 5/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.887, test=0.617) total time=  22.2s
# [CV 5/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.892, test=0.662) total time= 1.8min
# [CV] END C=0.001, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.001, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.001, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.001, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=30, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.798, test=0.551) total time=   3.6s
# [CV 2/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=0.999, test=0.584) total time=  21.2s
# [CV 4/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.870, test=0.611) total time=  21.4s
# [CV 1/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=(train=0.999, test=0.605) total time= 1.6min
# [CV 5/5] END bootstrap=True, criterion=gini, max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=1.000, test=0.605) total time=  46.2s
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.891, test=0.639) total time= 1.9min
# [CV] END C=0.001, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.001, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.001, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.001, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# ...
# [CV 1/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=10, n_estimators=100;, score=(train=0.889, test=0.638) total time= 1.8min
# [CV] END C=0.001, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.001, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.001, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.001, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# ----------
# iter: 2
# n_candidates: 11
# n_resources: 1044
# Fitting 5 folds for each of 11 candidates, totalling 55 fits
# [CV 4/5] END bootstrap=True, criterion=log_loss, max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=(train=0.897, test=0.666) total time= 1.2min
# [CV] END C=0.001, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.001, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.001, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.001, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.001, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.005179474679231213, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=3.7275937203149416, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# ----------
# iter: 3
# n_candidates: 4
# n_resources: 3132
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# ----------
# iter: 4
# n_candidates: 2
# n_resources: 9396
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# Best Params: {'C': np.float64(0.13894954943731375), 'class_weight': 'balanced', 'max_iter': 10000, 'tol': 0.0001}

# %%
best_svm = halving1.best_estimator_

y_test_pred = best_svm.predict(X_test)

# %%
print("Test Accuracy:", accuracy_score(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred))
# Out:
# Test Accuracy: 0.6546457361052185
#                precision    recall  f1-score   support
#
# non-sarcastic       0.65      0.66      0.66      1179
#     sarcastic       0.66      0.65      0.65      1178
#
#      accuracy                           0.65      2357
#     macro avg       0.65      0.65      0.65      2357
#  weighted avg       0.65      0.65      0.65      2357
#
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.1s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.1s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.1s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.1s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.1s
# [CV] END C=100.0, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.1s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.7196856730011522, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=None, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=19.306977288832496, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=0.0001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=100.0, class_weight=None, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.1s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=1e-05; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=5000, tol=0.001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.02682695795279726, class_weight=balanced, max_iter=10000, tol=1e-05; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.0s
# [CV] END C=0.13894954943731375, class_weight=balanced, max_iter=10000, tol=0.0001; total time=   0.1s

# %%
import joblib

joblib.dump(best_rf, "rf_model.joblib")
joblib.dump(best_svm, "lsvm_model.joblib")
# Out:
# ['lsvm_model.joblib']
